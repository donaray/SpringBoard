# %%
import pandas as pd

# %%
import json
from pandas.io.json import json_normalize
from collections import defaultdict, Counter

# %%
# load json as string
json.load((open('data/world_bank_projects_less.json')))
# Out:
# [{'_id': {'$oid': '52b213b38594d8a2be17c780'},
#   'approvalfy': 1999,
#   'board_approval_month': 'November',
#   'boardapprovaldate': '2013-11-12T00:00:00Z',
#   'borrower': 'FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA',
#   'closingdate': '2018-07-07T00:00:00Z',
#   'country_namecode': 'Federal Democratic Republic of Ethiopia!$!ET',
#   'countrycode': 'ET',
#   'countryname': 'Federal Democratic Republic of Ethiopia',
#   'countryshortname': 'Ethiopia',
#   'docty': 'Project Information Document,Indigenous Peoples Plan,Project Information Document',
#   'envassesmentcategorycode': 'C',
#   'grantamt': 0,
#   'ibrdcommamt': 0,
#   'id': 'P129828',
#   'idacommamt': 130000000,
#   'impagency': 'MINISTRY OF EDUCATION',
#   'lendinginstr': 'Investment Project Financing',
#   'lendinginstrtype': 'IN',
#   'lendprojectcost': 550000000,
#   'majorsector_percent': [{'Name': 'Education', 'Percent': 46},
#    {'Name': 'Education', 'Percent': 26},
# ...

# %%
# load as Pandas dataframe
sample_json_df = pd.read_json('data/world_bank_projects.json')
#sample_json_df

# %%
print(sample_json_df['countryname'][0])
# Out:
# Federal Democratic Republic of Ethiopia

# %%
print(sample_json_df['mjtheme_namecode'][0:10])
# Out:
# 0    [{'code': '8', 'name': 'Human development'}, {...
# 1    [{'code': '1', 'name': 'Economic management'},...
# 2    [{'code': '5', 'name': 'Trade and integration'...
# 3    [{'code': '7', 'name': 'Social dev/gender/incl...
# 4    [{'code': '5', 'name': 'Trade and integration'...
# 5    [{'code': '6', 'name': 'Social protection and ...
# 6    [{'code': '2', 'name': 'Public sector governan...
# 7    [{'code': '11', 'name': 'Environment and natur...
# 8    [{'code': '10', 'name': 'Rural development'}, ...
# 9    [{'code': '2', 'name': 'Public sector governan...
# Name: mjtheme_namecode, dtype: object

# %%
print(type(sample_json_df['mjtheme_namecode']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
dict_counter = defaultdict(int)

for countrycode, count in dict_counter:
    dict_counter[df['countrycode']] +=count 

for k, v in dict_counter.items():
    print(k, v)

for countrycode, count in sorted(dict_counter, key=dict_counter.__getitem__):
    print(countrycode, 'A')
    print('Not Good')

# %%
#sample_json_df['countrycode'] = sample_json_df['countrycode'].astype(str)
Country_freq = sample_json_df['countryname'].value_counts()

# %%
print(type(Country_freq))
print(Country_freq.sum())
# Out:
# <class 'pandas.core.series.Series'>
# 500

# %%
values_list = dict(Country_freq)
values_list = Counter(values_list)

# %%
for k, v in values_list.most_common(10):
    print(k, v)
# Out:
# People's Republic of China 19
# Republic of Indonesia 19
# Socialist Republic of Vietnam 17
# Republic of India 16
# Republic of Yemen 13
# People's Republic of Bangladesh 12
# Nepal 12
# Kingdom of Morocco 12
# Republic of Mozambique 11
# Africa 11

# %%
df_test = sample_json_df[['mjtheme_namecode']]
print(type(df_test))
#print(df_test['mjtheme_namecode'][0:10])
#Theme_freq = sample_json_df['mjtheme_namecode'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
pd.set_option('display.max_rows', None)
l_test = df_test['mjtheme_namecode'].tolist()
#print(l_test)

# %%
print(l_test[0:3])
# Out:
# [[{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}], [{'code': '1', 'name': 'Economic management'}, {'code': '6', 'name': 'Social protection and risk management'}], [{'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '6', 'name': 'Social protection and risk management'}]]

# %%
count_dict = defaultdict(int)
name_dict = defaultdict(str)

for index, row in sample_json_df.iterrows():  #for l in l_test:
    for j in row['mjtheme_namecode']:   #for j in l:
        for key, value in j.items():
            if key == 'code':
                count_dict[j[key]] += 1  
                #print(j[key])
                #print(my_dict[j[key]])
            elif key == 'name':
                if (j['name'] != ''):
                    name_dict[j['code']] = j['name']
                
                
 
#my_dict = Counter(my_dict)

# %%
new_dict = defaultdict(int)

for k1, v1 in count_dict.items():
    for k2, v2 in name_dict.items():
        if k1 == k2:
            new_dict[name_dict[k2]] = count_dict[k1]

new_dict = Counter(new_dict)            
            
for k, v in new_dict.most_common(12):
    print(k, v)
 
print('')

for k, v in name_dict.items():
    print(k, v)
# Out:
# Environment and natural resources management 250
# Rural development 216
# Human development 210
# Public sector governance 199
# Social protection and risk management 168
# Financial and private sector development 146
# Social dev/gender/inclusion 130
# Trade and integration 77
# Urban development 50
# Economic management 38
# Rule of law 15
#
# 8 Human development
# 11 Environment and natural resources management
# 1 Economic management
# 6 Social protection and risk management
# 5 Trade and integration
# 2 Public sector governance
# 7 Social dev/gender/inclusion
# 4 Financial and private sector development
# 10 Rural development
# 9 Urban development
# 3 Rule of law

# %%
print(sample_json_df['mjtheme_namecode'].head())
#for index, row in df_test.iterrows():
    #print(row['mjtheme_namecode'])
# Out:
# 0    [{'code': '8', 'name': 'Human development'}, {...
# 1    [{'code': '1', 'name': 'Economic management'},...
# 2    [{'code': '5', 'name': 'Trade and integration'...
# 3    [{'code': '7', 'name': 'Social dev/gender/incl...
# 4    [{'code': '5', 'name': 'Trade and integration'...
# Name: mjtheme_namecode, dtype: object

# %%
'''
for l in l_test:
    for j in l:
        for key, value in j.items():
            if key == 'code':
                code = j[key]
            elif key == 'name':
                if (j['name'] == ''):
                    j['name'] = name_dict[code]
                    '''

# %%
for index, row in sample_json_df.iterrows():
    for j in row['mjtheme_namecode']:
        #print(type(element_list))
        print(j)
        for key, value in j.items():
            if key == 'code':
                code = j[key]
            elif key == 'name':
                if (j['name'] == ''):
                    j['name'] = name_dict[code]
# Out:
# {'code': '8', 'name': 'Human development'}
# {'code': '11', 'name': 'Environment and natural resources management'}
# {'code': '1', 'name': 'Economic management'}
# {'code': '6', 'name': 'Social protection and risk management'}
# {'code': '5', 'name': 'Trade and integration'}
# {'code': '2', 'name': 'Public sector governance'}
# {'code': '11', 'name': 'Environment and natural resources management'}
# {'code': '6', 'name': 'Social protection and risk management'}
# {'code': '7', 'name': 'Social dev/gender/inclusion'}
# {'code': '7', 'name': 'Social dev/gender/inclusion'}
# {'code': '5', 'name': 'Trade and integration'}
# {'code': '4', 'name': 'Financial and private sector development'}
# {'code': '6', 'name': 'Social protection and risk management'}
# {'code': '6', 'name': 'Social protection and risk management'}
# {'code': '2', 'name': 'Public sector governance'}
# {'code': '4', 'name': 'Financial and private sector development'}
# ...

# %%
#print(sample_json_df.info())
print(sample_json_df['mjtheme_namecode'][0:10])
# Out:
# 0    [{'code': '8', 'name': 'Human development'}, {...
# 1    [{'code': '1', 'name': 'Economic management'},...
# 2    [{'code': '5', 'name': 'Trade and integration'...
# 3    [{'code': '7', 'name': 'Social dev/gender/incl...
# 4    [{'code': '5', 'name': 'Trade and integration'...
# 5    [{'code': '6', 'name': 'Social protection and ...
# 6    [{'code': '2', 'name': 'Public sector governan...
# 7    [{'code': '11', 'name': 'Environment and natur...
# 8    [{'code': '10', 'name': 'Rural development'}, ...
# 9    [{'code': '2', 'name': 'Public sector governan...
# Name: mjtheme_namecode, dtype: object

# %%
print(l_test)
# Out:
# [[{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': 'Environment and natural resources management'}], [{'code': '1', 'name': 'Economic management'}, {'code': '6', 'name': 'Social protection and risk management'}], [{'code': '5', 'name': 'Trade and integration'}, {'code': '2', 'name': 'Public sector governance'}, {'code': '11', 'name': 'Environment and natural resources management'}, {'code': '6', 'name': 'Social protection and risk management'}], [{'code': '7', 'name': 'Social dev/gender/inclusion'}, {'code': '7', 'name': 'Social dev/gender/inclusion'}], [{'code': '5', 'name': 'Trade and integration'}, {'code': '4', 'name': 'Financial and private sector development'}], [{'code': '6', 'name': 'Social protection and risk management'}, {'code': '6', 'name': 'Social protection and risk management'}], [{'code': '2', 'name': 'Public sector governance'}, {'code': '4', 'name': 'Financial and private sector development'}], [{'code': '11', 'name': 'Environment and natural reso
# ...

# %%
print(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
# 0    500 non-null object
# 1    491 non-null object
# 2    263 non-null object
# 3    171 non-null object
# 4    74 non-null object
# dtypes: object(5)
# memory usage: 19.6+ KB
# None
